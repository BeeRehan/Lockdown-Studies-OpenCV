# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = np.random.randint(0,10,(10),int)
arr
# Out:
# array([1, 8, 5, 6, 3, 0, 7, 4, 3, 2])

# %%
plt.plot(arr)
